# %% [markdown]
# # The Basics Of Canva - Masterclass

# %% [markdown]
# ## Step 1 : Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mc_c_df = pd.read_excel("C:/Users/Alina Sahoo/Documents/MKR/Task2/Masterclass on Basics of Canva - a Graphic Design Platform (Responses).xlsx")

# %%
mc_c_df.head() #loads the values of first five data
# Out:
#                 Timestamp First Name  Last Name        City Unnamed: 4  \
# 0 2020-08-09 21:10:59.330      Anuja    Kharkar      Bhopal      canva
# 1 2020-08-09 21:27:42.550  Abhishek   Bhardwaj    New delhi      canva
# 2 2020-08-09 21:29:55.608    Manjiri     Sonone        Pune      canva
# 3 2020-08-09 21:30:34.752    Anthima      Singh  Hyderabad       canva
# 4 2020-08-09 21:36:48.633    Dharini       Shah      Mumbai      canva
#
#                 Unnamed: 5
# 0        canvaAnujaKharkar
# 1  canvaAbhishek Bhardwaj
# 2       canvaManjiriSonone
# 3        canvaAnthimaSingh
# 4         canvaDhariniShah

# %%
mc_c_df.tail() #loads the values of last five data
# Out:
#                   Timestamp First Name Last Name        City Unnamed: 4  \
# 661 2020-08-23 11:11:02.135       Neha         H        Pune      canva
# 662 2020-08-23 12:14:59.449     Radha     Ranade        Pune      canva
# 663 2020-08-23 14:05:04.953     Namita      Soni       Korba      canva
# 664 2020-08-23 14:05:46.067    Swapnil     Nikam  Aurangabad      canva
# 665 2020-08-23 14:12:46.954    Darshan         M      mysore      canva
#
#             Unnamed: 5
# 661         canvaNehaH
# 662  canvaRadha Ranade
# 663    canvaNamitaSoni
# 664  canvaSwapnilNikam
# 665      canvaDarshanM

# %%
mc_c_df.info() #precise information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 666 entries, 0 to 665
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   666 non-null    datetime64[ns]
#  1   First Name  666 non-null    object
#  2   Last Name   666 non-null    object
#  3   City        666 non-null    object
#  4   Unnamed: 4  666 non-null    object
#  5   Unnamed: 5  666 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 31.3+ KB

# %%
mc_c_df.isna().sum() #checks for the missing values if any
# Out:
# Timestamp     0
# First Name    0
# Last Name     0
# City          0
# Unnamed: 4    0
# Unnamed: 5    0
# dtype: int64

# %%
mc_c_df.columns
# Out:
# Index(['Timestamp', 'First Name', 'Last Name', 'City', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %% [markdown]
# ## Step 2 : Data Cleaning

# %%
mc_c_df.drop(columns=['Unnamed: 4', 'Unnamed: 5'], inplace=True) #dropping unnecessary columns

# %%
mc_c_df
# Out:
#                   Timestamp First Name  Last Name        City
# 0   2020-08-09 21:10:59.330      Anuja    Kharkar      Bhopal
# 1   2020-08-09 21:27:42.550  Abhishek   Bhardwaj    New delhi
# 2   2020-08-09 21:29:55.608    Manjiri     Sonone        Pune
# 3   2020-08-09 21:30:34.752    Anthima      Singh  Hyderabad
# 4   2020-08-09 21:36:48.633    Dharini       Shah      Mumbai
# ..                      ...        ...        ...         ...
# 661 2020-08-23 11:11:02.135       Neha          H        Pune
# 662 2020-08-23 12:14:59.449     Radha      Ranade        Pune
# 663 2020-08-23 14:05:04.953     Namita       Soni       Korba
# 664 2020-08-23 14:05:46.067    Swapnil      Nikam  Aurangabad
# 665 2020-08-23 14:12:46.954    Darshan          M      mysore
#
# [666 rows x 4 columns]

# %%
mc_c_df["First Name"]= mc_c_df["First Name"].str.upper().str.title() 
mc_c_df["Last Name"]= mc_c_df["Last Name"].str.upper().str.title()

# %%
mc_c_df.head(30)
# Out:
#                  Timestamp    First Name          Last Name             City
# 0  2020-08-09 21:10:59.330         Anuja            Kharkar           Bhopal
# 1  2020-08-09 21:27:42.550     Abhishek           Bhardwaj         New delhi
# 2  2020-08-09 21:29:55.608       Manjiri             Sonone             Pune
# 3  2020-08-09 21:30:34.752       Anthima              Singh       Hyderabad
# 4  2020-08-09 21:36:48.633       Dharini               Shah           Mumbai
# 5  2020-08-09 21:37:08.225      Harshita              Ahuja            Delhi
# 6  2020-08-09 21:40:43.168      Prajakta              Shaha             Pune
# 7  2020-08-09 21:41:47.967        Soumya              Meher             Pune
# 8  2020-08-09 21:48:44.739  Mehak Bansal            Bansal            Delhi
# 9  2020-08-09 21:58:31.337       Namita               Ahuja        Allahabad
# 10 2020-08-09 22:00:32.768       Shreya              Biswas          Bhilai
# ...

# %%
mc_c_df['First Name'] = mc_c_df['First Name'].replace(['Mehak Bansal'],'Mehak')

mc_c_df['City'] = mc_c_df['City'].replace(['SARAN( CHAPRA )'],'Chapra')
mc_c_df['City'] = mc_c_df['City'].replace(['Saharanpur, UP'],'Saharanpur')
mc_c_df['City'] = mc_c_df['City'].replace(['Thane West Mumbai'],'Thane West')
mc_c_df['City'] = mc_c_df['City'].replace(['Pimpri Chinchwad'],'Pimpri-Chinchwad')
mc_c_df['City'] = mc_c_df['City'].replace(['BASTAR CHHATTISGARH'],'Bastar')
mc_c_df['City'] = mc_c_df['City'].replace(['ruchitamagr412@gmail.com'],'Patna')
mc_c_df['City'] = mc_c_df['City'].replace(['Beltola, Guwahati'],'Beltola Tiniali')
mc_c_df['City'] = mc_c_df['City'].replace(['Baripada, Mayurbhanj'],'Baripada')
mc_c_df['City'] = mc_c_df['City'].replace(['Agra, Uttar Pradesh'],'Agra')
mc_c_df['City'] = mc_c_df['City'].replace(['Shahdara, North East Delhi'],'Shahdara')
mc_c_df['City'] = mc_c_df['City'].replace(['Mumbai City'],'Mumbai')
mc_c_df['City'] = mc_c_df['City'].replace(['Delhi/Lucknow'],'Lucknow')
mc_c_df['City'] = mc_c_df['City'].replace(['Kottayam, Kerala'],'Kottayam')
mc_c_df['City'] = mc_c_df['City'].replace(['Kampala, Uganda'],'Kampala')
mc_c_df['City'] = mc_c_df['City'].replace(['Haryana ,Delhi'],'Delhi')
mc_c_df['City'] = mc_c_df['City'].replace(['Azamgarh u.p'],'Azamgarh')
mc_c_df['City'] = mc_c_df['City'].replace(['Patna (Bihar) '],'Patna')
mc_c_df['City'] = mc_c_df['City'].replace(['Chittaranjan West Bengal'],'Chittaranjan')
mc_c_df['City'] = mc_c_df['City'].replace(['Navi Mumbai-410210'],'Navi Mumbai')
mc_c_df['City'] = mc_c_df['City'].replace(['Velachery, Chennai'],'Velachery')
mc_c_df['City'] = mc_c_df['City'].replace(['bhubaneswar,ODISHA'],'Bhubaneswar')
mc_c_df['City'] = mc_c_df['City'].replace(['Shamli U.P.'],'Shamli')
mc_c_df['City'] = mc_c_df['City'].replace(['Kamrup Metro'],'Kamrup Metropolitan')
mc_c_df['City'] = mc_c_df['City'].replace(['CALOOCAN CITY'],'Caloocan')
mc_c_df['City'] = mc_c_df['City'].replace(['Jamnagar, Gujarat'],'Jamnagar')
mc_c_df['City'] = mc_c_df['City'].replace(['Karachi, Pakistan'],'Karachi')
mc_c_df['City'] = mc_c_df['City'].replace(['Manila, Philippines'],'Manila')
mc_c_df['City'] = mc_c_df['City'].replace(['North West Delhi'],'Delhi')
mc_c_df['City'] = mc_c_df['City'].replace(['Mumbai/Lucknow'],'Lucknow')
mc_c_df['City'] = mc_c_df['City'].replace(['Balangir, Odisha'],'Balangir')
mc_c_df['City'] = mc_c_df['City'].replace(['Quezon City Philippines'],'Quezon City')
mc_c_df['City'] = mc_c_df['City'].replace(['Shahjahanpur UP'],'Shahjahanpur')
mc_c_df['City'] = mc_c_df['City'].replace(['Akola,(maharashtra)'],'Akola')
mc_c_df['City'] = mc_c_df['City'].replace(['Valencia City, Bukidnon'],'Valencia City')
mc_c_df['City'] = mc_c_df['City'].replace(['Vellorr Tamilnadu'],'Vellore')

# %%
mc_c_df["City"]= mc_c_df["City"].str.upper().str.title()

# %%
mc_c_df.head()
# Out:
#                 Timestamp First Name  Last Name        City
# 0 2020-08-09 21:10:59.330      Anuja    Kharkar      Bhopal
# 1 2020-08-09 21:27:42.550  Abhishek   Bhardwaj    New Delhi
# 2 2020-08-09 21:29:55.608    Manjiri     Sonone        Pune
# 3 2020-08-09 21:30:34.752    Anthima      Singh  Hyderabad
# 4 2020-08-09 21:36:48.633    Dharini       Shah      Mumbai

# %%
mc_c_df.insert(4, "MasterClass Name", "The Basics of Canva")

# %%
mc_c_df
# Out:
#                   Timestamp First Name  Last Name        City  \
# 0   2020-08-09 21:10:59.330      Anuja    Kharkar      Bhopal
# 1   2020-08-09 21:27:42.550  Abhishek   Bhardwaj    New Delhi
# 2   2020-08-09 21:29:55.608    Manjiri     Sonone        Pune
# 3   2020-08-09 21:30:34.752    Anthima      Singh  Hyderabad
# 4   2020-08-09 21:36:48.633    Dharini       Shah      Mumbai
# ..                      ...        ...        ...         ...
# 661 2020-08-23 11:11:02.135       Neha          H        Pune
# 662 2020-08-23 12:14:59.449     Radha      Ranade        Pune
# 663 2020-08-23 14:05:04.953     Namita       Soni       Korba
# 664 2020-08-23 14:05:46.067    Swapnil      Nikam  Aurangabad
# 665 2020-08-23 14:12:46.954    Darshan          M      Mysore
#
#         MasterClass Name
# 0    The Basics of Canva
# 1    The Basics of Canva
# 2    The Basics of Canva
# 3    The Basics of Canva
# 4    The Basics of Canva
# ..                   ...
# 661  The Basics of Canva
# ...

# %%
mc_c_df.to_excel(r'C:\Users\Alina Sahoo\Documents\MKR\Task2\MC4.xlsx', index = False)
