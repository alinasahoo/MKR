# %% [markdown]
# # Public Speaking - Masterclass

# %% [markdown]
# ## Step 1 : Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mc_p_df = pd.read_excel("C:/Users/Alina Sahoo/Documents/MKR/Task2/Public Speaking - Masterclass (Responses).xlsx")

# %%
mc_p_df.head() #loads the values of first five data
# Out:
#                 Timestamp First Name  Last Name            City Unnamed: 4  \
# 0 2020-08-02 15:05:28.216      saket   deshmukh            Pune     Public
# 1 2020-08-02 22:13:36.424    Mishika     Sharma         Gurgaon     Public
# 2 2020-08-02 22:16:43.616     Diksha        Deb  Silchar, Assam     Public
# 3 2020-08-02 22:17:19.184     Lohith  Bollineni         Chennai     Public
# 4 2020-08-02 22:20:47.635     Rutuja   Ghorpade            Pune     Public
#
#               Unnamed: 5
# 0    Publicsaketdeshmukh
# 1    PublicMishikaSharma
# 2        PublicDikshaDeb
# 3  PublicLohithBollineni
# 4   PublicRutujaGhorpade

# %%
mc_p_df.tail() #loads the values of last five data
# Out:
#                   Timestamp  First Name    Last Name       City Unnamed: 4  \
# 190 2020-08-09 12:43:14.707       Ronak         Shah     Mumbai     Public
# 191 2020-08-09 12:53:47.614    Vaibhav         Daksh      Delhi     Public
# 192 2020-08-09 13:03:52.081  Vaishnavi   Kshirsagar        Pune     Public
# 193 2020-08-09 13:17:34.780     Vaibhav        Daksh  Delhi ncr     Public
# 194 2020-08-09 14:03:36.349    Richelle       Aranjo       Pune     Public
#
#                       Unnamed: 5
# 190              PublicRonakShah
# 191          PublicVaibhav Daksh
# 192  PublicVaishnavi Kshirsagar
# 193           PublicVaibhavDaksh
# 194         PublicRichelleAranjo

# %%
mc_p_df.info() #precise information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   195 non-null    datetime64[ns]
#  1   First Name  195 non-null    object
#  2   Last Name   195 non-null    object
#  3   City        195 non-null    object
#  4   Unnamed: 4  195 non-null    object
#  5   Unnamed: 5  195 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 9.3+ KB

# %%
mc_p_df.isna().sum() #checks for the missing values if any
# Out:
# Timestamp     0
# First Name    0
# Last Name     0
# City          0
# Unnamed: 4    0
# Unnamed: 5    0
# dtype: int64

# %%
mc_p_df.columns
# Out:
# Index(['Timestamp', 'First Name', 'Last Name', 'City', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %% [markdown]
# ## Step 2 : Data Cleaning

# %%
mc_p_df.drop(columns=['Unnamed: 4', 'Unnamed: 5'], inplace=True) #dropping unnecessary columns

# %%
mc_p_df
# Out:
#                   Timestamp  First Name    Last Name            City
# 0   2020-08-02 15:05:28.216       saket     deshmukh            Pune
# 1   2020-08-02 22:13:36.424     Mishika       Sharma         Gurgaon
# 2   2020-08-02 22:16:43.616      Diksha          Deb  Silchar, Assam
# 3   2020-08-02 22:17:19.184      Lohith    Bollineni         Chennai
# 4   2020-08-02 22:20:47.635      Rutuja     Ghorpade            Pune
# ..                      ...         ...          ...             ...
# 190 2020-08-09 12:43:14.707       Ronak         Shah          Mumbai
# 191 2020-08-09 12:53:47.614    Vaibhav         Daksh           Delhi
# 192 2020-08-09 13:03:52.081  Vaishnavi   Kshirsagar             Pune
# 193 2020-08-09 13:17:34.780     Vaibhav        Daksh       Delhi ncr
# 194 2020-08-09 14:03:36.349    Richelle       Aranjo            Pune
#
# [195 rows x 4 columns]

# %%
mc_p_df["First Name"]= mc_p_df["First Name"].str.upper().str.title() 
mc_p_df["Last Name"]= mc_p_df["Last Name"].str.upper().str.title()

# %%
mc_p_df.head(30)
# Out:
#                  Timestamp    First Name   Last Name            City
# 0  2020-08-02 15:05:28.216         Saket    Deshmukh            Pune
# 1  2020-08-02 22:13:36.424       Mishika      Sharma         Gurgaon
# 2  2020-08-02 22:16:43.616        Diksha         Deb  Silchar, Assam
# 3  2020-08-02 22:17:19.184        Lohith   Bollineni         Chennai
# 4  2020-08-02 22:20:47.635        Rutuja    Ghorpade            Pune
# 5  2020-08-02 22:28:34.937         Vyomi     Gidwani            Pune
# 6  2020-08-02 22:29:13.224       Swapnil    Agrahari       Gorakhpur
# 7  2020-08-02 23:02:07.953    Umme-Aiman  Rampurwala            Pune
# 8  2020-08-03 08:46:24.790         Soham         Roy        Jamnagar
# 9  2020-08-03 12:00:12.513     Shravani      D'Souza            Pune
# 10 2020-08-03 12:02:34.760       Mayank      Chauhan        Solapur
# 11 2020-08-03 12:02:45.902  Raktim Kumar        Nath       Morigaon
# 12 2020-08-03 12:03:14.113       Nitish     Chorghe          Mumbai
# ...

# %%
mc_p_df['City'] = mc_p_df['City'].replace(['Silchar, Assam'],'Silchar')
mc_p_df['City'] = mc_p_df['City'].replace(['Tripunithura, Ernakulam'],'Thrippunithura')
mc_p_df['City'] = mc_p_df['City'].replace(['Trivandrum, Kerala'],'Thiruvananthapuram')
mc_p_df['City'] = mc_p_df['City'].replace(['Navi Mumbai-410210'],'Navi Mumbai')
mc_p_df['City'] = mc_p_df['City'].replace(['Rayagada, Odisha.'],'Rayagada')
mc_p_df['City'] = mc_p_df['City'].replace(['Thane Maharashtra'],'Thane')
mc_p_df['City'] = mc_p_df['City'].replace(['Egypt - Damietta'],'Damietta')
mc_p_df['City'] = mc_p_df['City'].replace([' Baler Aurora Philippines'],'Baler')
mc_p_df['City'] = mc_p_df['City'].replace(['Hoshangabad m.p.'],'Hoshangabad')
mc_p_df['City'] = mc_p_df['City'].replace(['Los Baños, Philippines'],'Los Baños')
mc_p_df['City'] = mc_p_df['City'].replace(['Delhi ncr'],'Delhi')
mc_p_df['City'] = mc_p_df['City'].replace(['Ambejogai'],'Ambajogai')

# %%
mc_p_df["City"]= mc_p_df["City"].str.upper().str.title()

# %%
mc_p_df.head(30)
# Out:
#                  Timestamp    First Name   Last Name        City
# 0  2020-08-02 15:05:28.216         Saket    Deshmukh        Pune
# 1  2020-08-02 22:13:36.424       Mishika      Sharma     Gurgaon
# 2  2020-08-02 22:16:43.616        Diksha         Deb     Silchar
# 3  2020-08-02 22:17:19.184        Lohith   Bollineni     Chennai
# 4  2020-08-02 22:20:47.635        Rutuja    Ghorpade        Pune
# 5  2020-08-02 22:28:34.937         Vyomi     Gidwani        Pune
# 6  2020-08-02 22:29:13.224       Swapnil    Agrahari   Gorakhpur
# 7  2020-08-02 23:02:07.953    Umme-Aiman  Rampurwala        Pune
# 8  2020-08-03 08:46:24.790         Soham         Roy    Jamnagar
# 9  2020-08-03 12:00:12.513     Shravani      D'Souza        Pune
# 10 2020-08-03 12:02:34.760       Mayank      Chauhan    Solapur
# 11 2020-08-03 12:02:45.902  Raktim Kumar        Nath   Morigaon
# 12 2020-08-03 12:03:14.113       Nitish     Chorghe      Mumbai
# ...

# %%
mc_p_df.insert(4, "MasterClass Name", "Public Speaking")

# %%
mc_p_df
# Out:
#                   Timestamp  First Name    Last Name     City MasterClass Name
# 0   2020-08-02 15:05:28.216       Saket     Deshmukh     Pune  Public Speaking
# 1   2020-08-02 22:13:36.424     Mishika       Sharma  Gurgaon  Public Speaking
# 2   2020-08-02 22:16:43.616      Diksha          Deb  Silchar  Public Speaking
# 3   2020-08-02 22:17:19.184      Lohith    Bollineni  Chennai  Public Speaking
# 4   2020-08-02 22:20:47.635      Rutuja     Ghorpade     Pune  Public Speaking
# ..                      ...         ...          ...      ...              ...
# 190 2020-08-09 12:43:14.707       Ronak         Shah   Mumbai  Public Speaking
# 191 2020-08-09 12:53:47.614    Vaibhav         Daksh    Delhi  Public Speaking
# 192 2020-08-09 13:03:52.081  Vaishnavi   Kshirsagar      Pune  Public Speaking
# 193 2020-08-09 13:17:34.780     Vaibhav        Daksh    Delhi  Public Speaking
# 194 2020-08-09 14:03:36.349    Richelle       Aranjo     Pune  Public Speaking
#
# [195 rows x 5 columns]

# %%
mc_p_df.to_excel(r'C:\Users\Alina Sahoo\Documents\MKR\Task2\MC5.xlsx', index = False)
