# %% [markdown]
# # What'sApp Marketing - Masterclass

# %% [markdown]
# ## Step 1 : Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mc_wm_df = pd.read_excel("C:/Users/Alina Sahoo/Documents/MKR/Task2/Masterclass on - Whatsapp Marketing (Responses).xlsx")

# %%
mc_wm_df.head() #loads the values of first five data
# Out:
#                 Timestamp    First Name Last Name        City Unnamed: 4  \
# 0 2020-08-29 11:31:02.261           Raj      Maru      Mumbai   whatsapp
# 1 2020-08-29 16:33:59.010       Prachi   Agarwal   Moradabad    whatsapp
# 2 2020-08-29 18:08:10.918  Paramananda       Deka    Guwahati   whatsapp
# 3 2020-08-29 19:36:26.061        Rajesh     Kumar   Raebareli   whatsapp
# 4 2020-08-29 19:40:57.353     Akanksha     Kunwar    Dehradun   whatsapp
#
#                  Unnamed: 5
# 0           whatsappRajMaru
# 1   whatsappPrachi Agarwal
# 2  whatsappParamananda Deka
# 3       whatsappRajeshKumar
# 4   whatsappAkanksha Kunwar

# %%
mc_wm_df.tail() #loads the values of last five data
# Out:
#                   Timestamp First Name Last Name          City Unnamed: 4  \
# 384 2020-09-13 13:58:24.409     Nimesh     Desai          Pune   whatsapp
# 385 2020-09-13 13:58:54.267     Vedant    Musale          Pune   whatsapp
# 386 2020-09-13 14:10:46.382    Pushkar      Shah          Pune   whatsapp
# 387 2020-09-13 14:30:02.398   Satyajit     Kadam          Pune   whatsapp
# 388 2020-09-13 15:04:32.596      Sneha     Bugad  Ichalkaranji   whatsapp
#
#                 Unnamed: 5
# 384    whatsappNimeshDesai
# 385   whatsappVedantMusale
# 386    whatsappPushkarShah
# 387  whatsappSatyajitKadam
# 388     whatsappSnehaBugad

# %%
mc_wm_df.info() #precise information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   389 non-null    datetime64[ns]
#  1   First Name  389 non-null    object
#  2   Last Name   389 non-null    object
#  3   City        389 non-null    object
#  4   Unnamed: 4  389 non-null    object
#  5   Unnamed: 5  389 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 18.4+ KB

# %%
mc_wm_df.isna().sum() #checks for the missing values if any
# Out:
# Timestamp     0
# First Name    0
# Last Name     0
# City          0
# Unnamed: 4    0
# Unnamed: 5    0
# dtype: int64

# %%
mc_wm_df.columns
# Out:
# Index(['Timestamp', 'First Name', 'Last Name', 'City', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %% [markdown]
# ## Step 2 : Data Cleaning

# %%
mc_wm_df.drop(columns=['Unnamed: 4', 'Unnamed: 5'], inplace=True) #dropping unnecessary columns

# %%
mc_wm_df
# Out:
#                   Timestamp    First Name Last Name          City
# 0   2020-08-29 11:31:02.261           Raj      Maru        Mumbai
# 1   2020-08-29 16:33:59.010       Prachi   Agarwal     Moradabad
# 2   2020-08-29 18:08:10.918  Paramananda       Deka      Guwahati
# 3   2020-08-29 19:36:26.061        Rajesh     Kumar     Raebareli
# 4   2020-08-29 19:40:57.353     Akanksha     Kunwar      Dehradun
# ..                      ...           ...       ...           ...
# 384 2020-09-13 13:58:24.409        Nimesh     Desai          Pune
# 385 2020-09-13 13:58:54.267        Vedant    Musale          Pune
# 386 2020-09-13 14:10:46.382       Pushkar      Shah          Pune
# 387 2020-09-13 14:30:02.398      Satyajit     Kadam          Pune
# 388 2020-09-13 15:04:32.596         Sneha     Bugad  Ichalkaranji
#
# [389 rows x 4 columns]

# %%
mc_wm_df["First Name"]= mc_wm_df["First Name"].str.upper().str.title() 
mc_wm_df["Last Name"]= mc_wm_df["Last Name"].str.upper().str.title()
mc_wm_df["City"]= mc_wm_df["City"].str.upper().str.title()

# %%
mc_wm_df.head(30)
# Out:
#                  Timestamp    First Name    Last Name  \
# 0  2020-08-29 11:31:02.261           Raj         Maru
# 1  2020-08-29 16:33:59.010       Prachi      Agarwal
# 2  2020-08-29 18:08:10.918  Paramananda          Deka
# 3  2020-08-29 19:36:26.061        Rajesh        Kumar
# 4  2020-08-29 19:40:57.353     Akanksha        Kunwar
# 5  2020-08-29 20:39:08.642        Paresh         Shah
# 6  2020-08-29 22:36:45.547        Lohit        Boruah
# 7  2020-08-30 00:57:09.930      Kushagra        Kumar
# 8  2020-08-30 09:13:26.631        Sanaya        Nayak
# 9  2020-08-30 12:17:39.441      Anindita        Dutta
# 10 2020-08-30 15:28:23.714        Deepti     Bhardwaj
# 11 2020-08-30 22:51:16.466        Shreya       Biswas
# 12 2020-08-31 01:33:00.696    Dharamdeep       Randev
# 13 2020-08-31 07:46:05.561          Manu          C M
# 14 2020-08-31 11:56:35.356      Ashutosh         Soni
# 15 2020-08-31 12:12:17.961       Akshat        Sharma
# ...

# %%
mc_wm_df['City'] = mc_wm_df['City'].replace(['Kharghar, Navi Mumbai - 410210'],'Mumbai')
mc_wm_df['City'] = mc_wm_df['City'].replace(['Deulgaon Raja,Buldana'],'Deulgaon Raja')
mc_wm_df['City'] = mc_wm_df['City'].replace(['Nagpur Maharashtra'],'Nagpur')
mc_wm_df['City'] = mc_wm_df['City'].replace(['Ahmedabad, Gujarat'],'Ahmedabad')
mc_wm_df['City'] = mc_wm_df['City'].replace(['Latur maharashtra '],'Latur')
mc_wm_df['City'] = mc_wm_df['City'].replace(['V.P.O - Mohanpur, DISTT. - Rewari (Haryana)'],'Rewari')
mc_wm_df['City'] = mc_wm_df['City'].replace(['Delhi NCR'],'New Delhi')
mc_wm_df['City'] = mc_wm_df['City'].replace(['Amravati, Maharashtra '],'Amravati')
mc_wm_df['City'] = mc_wm_df['City'].replace(['Nagaon, Assam. '],'Nagaon')
mc_wm_df['City'] = mc_wm_df['City'].replace(['Malegaon, Nashik'],'Malegaon')

# %%
mc_wm_df.head()
# Out:
#                 Timestamp    First Name Last Name        City
# 0 2020-08-29 11:31:02.261           Raj      Maru      Mumbai
# 1 2020-08-29 16:33:59.010       Prachi   Agarwal   Moradabad
# 2 2020-08-29 18:08:10.918  Paramananda       Deka    Guwahati
# 3 2020-08-29 19:36:26.061        Rajesh     Kumar   Raebareli
# 4 2020-08-29 19:40:57.353     Akanksha     Kunwar    Dehradun

# %%
mc_wm_df.insert(4, "MasterClass Name", "WhatsApp Marketing")

# %%
mc_wm_df.head()
# Out:
#                 Timestamp    First Name Last Name        City  \
# 0 2020-08-29 11:31:02.261           Raj      Maru      Mumbai
# 1 2020-08-29 16:33:59.010       Prachi   Agarwal   Moradabad
# 2 2020-08-29 18:08:10.918  Paramananda       Deka    Guwahati
# 3 2020-08-29 19:36:26.061        Rajesh     Kumar   Raebareli
# 4 2020-08-29 19:40:57.353     Akanksha     Kunwar    Dehradun
#
#      MasterClass Name
# 0  WhatsApp Marketing
# 1  WhatsApp Marketing
# 2  WhatsApp Marketing
# 3  WhatsApp Marketing
# 4  WhatsApp Marketing

# %%
mc_wm_df.to_excel(r'C:\Users\Alina Sahoo\Documents\MKR\Task2\MC1.xlsx', index = False)
