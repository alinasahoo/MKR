# %% [markdown]
# # Basic Video Editting - Masterclass

# %% [markdown]
# ## Step 1 : Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mc_ve_df = pd.read_excel("C:/Users/Alina Sahoo/Documents/MKR/Task2/Basic Video Editing - Masterclass (Responses).xlsx")

# %%
mc_ve_df.head() #loads the values of first five data
# Out:
#                 Timestamp         First Name      City Last Name Unnamed: 4
# 0 2020-07-28 16:46:31.177            Samrita    Raipur       NaN        NaN
# 1 2020-07-28 16:46:43.534     Khushi Tiwari   Gurgaon        NaN        NaN
# 2 2020-07-28 16:48:02.362      Shreya Biswas    Bhilai       NaN        NaN
# 3 2020-07-28 16:49:58.147       Hardik Patni      Pune       NaN        NaN
# 4 2020-07-28 16:50:17.182  Anhad Preet Singh   Chennai       NaN        NaN

# %%
mc_ve_df.tail() #loads the values of last five data
# Out:
#                   Timestamp   First Name        City     Last Name Unnamed: 4
# 581 2020-08-02 14:05:45.856      Kalyani        Pune           Jha        NaN
# 582 2020-08-02 20:13:55.905  Prathyusha   Kondapalli   Vangaveeti         NaN
# 583 2020-08-04 01:22:17.969    Munnawar         Pune  Nagarbawadi         NaN
# 584 2020-08-04 08:51:10.272       Souvik    Guwahati           das        NaN
# 585 2020-09-11 19:01:30.905        Manan        Pune      Sanghnai        NaN

# %%
mc_ve_df.info() #precise information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   586 non-null    datetime64[ns]
#  1   First Name  586 non-null    object
#  2   City        586 non-null    object
#  3   Last Name   205 non-null    object
#  4   Unnamed: 4  115 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 23.0+ KB

# %%
mc_ve_df.isna().sum() #checks for the missing values if any
# Out:
# Timestamp       0
# First Name      0
# City            0
# Last Name     381
# Unnamed: 4    471
# dtype: int64

# %%
mc_ve_df.columns
# Out:
# Index(['Timestamp', 'First Name', 'City', 'Last Name', 'Unnamed: 4'], dtype='object')

# %% [markdown]
# ## Step 2 : Data Cleaning

# %%
mc_ve_df.drop(columns=['Last Name', 'Unnamed: 4'], inplace=True) #dropping unnecessary columns

# %%
mc_ve_df
# Out:
#                   Timestamp         First Name        City
# 0   2020-07-28 16:46:31.177            Samrita      Raipur
# 1   2020-07-28 16:46:43.534     Khushi Tiwari     Gurgaon
# 2   2020-07-28 16:48:02.362      Shreya Biswas      Bhilai
# 3   2020-07-28 16:49:58.147       Hardik Patni        Pune
# 4   2020-07-28 16:50:17.182  Anhad Preet Singh     Chennai
# ..                      ...                ...         ...
# 581 2020-08-02 14:05:45.856            Kalyani        Pune
# 582 2020-08-02 20:13:55.905        Prathyusha   Kondapalli
# 583 2020-08-04 01:22:17.969          Munnawar         Pune
# 584 2020-08-04 08:51:10.272             Souvik    Guwahati
# 585 2020-09-11 19:01:30.905              Manan        Pune
#
# [586 rows x 3 columns]

# %%
mc_ve_df["First Name"]= mc_ve_df["First Name"].str.upper().str.title()

# %%
mc_ve_df.head(30)
# Out:
#                  Timestamp                 First Name         City
# 0  2020-07-28 16:46:31.177                    Samrita       Raipur
# 1  2020-07-28 16:46:43.534             Khushi Tiwari      Gurgaon
# 2  2020-07-28 16:48:02.362              Shreya Biswas       Bhilai
# 3  2020-07-28 16:49:58.147               Hardik Patni         Pune
# 4  2020-07-28 16:50:17.182          Anhad Preet Singh      Chennai
# 5  2020-07-28 16:50:32.636             Dhaval R Gupta    Bangalore
# 6  2020-07-28 16:52:14.244            Atharva Karande         Pune
# 7  2020-07-28 16:52:37.649            Sakshi Gulwani          Pune
# 8  2020-07-28 16:53:24.838           Manasva Bhargava       Bhopal
# 9  2020-07-28 16:53:54.094                 Umme-Aiman         Pune
# 10 2020-07-28 16:54:18.517                Rajdeep Das      Silchar
# 11 2020-07-28 16:54:19.959         Satyabrat Bordoloi       Jorhat
# 12 2020-07-28 16:55:27.891      Bharadwaj Prasad Roy   Bilasipara
# ...

# %%
mc_ve_df["City"]= mc_ve_df["City"].str.upper().str.title()

# %%
mc_ve_df.head()
# Out:
#                 Timestamp         First Name      City
# 0 2020-07-28 16:46:31.177            Samrita    Raipur
# 1 2020-07-28 16:46:43.534     Khushi Tiwari   Gurgaon
# 2 2020-07-28 16:48:02.362      Shreya Biswas    Bhilai
# 3 2020-07-28 16:49:58.147       Hardik Patni      Pune
# 4 2020-07-28 16:50:17.182  Anhad Preet Singh   Chennai

# %%
mc_ve_df.insert(3, "MasterClass Name", "Basic Video Editting")

# %%
mc_ve_df
# Out:
#                   Timestamp         First Name        City  \
# 0   2020-07-28 16:46:31.177            Samrita      Raipur
# 1   2020-07-28 16:46:43.534     Khushi Tiwari     Gurgaon
# 2   2020-07-28 16:48:02.362      Shreya Biswas      Bhilai
# 3   2020-07-28 16:49:58.147       Hardik Patni        Pune
# 4   2020-07-28 16:50:17.182  Anhad Preet Singh     Chennai
# ..                      ...                ...         ...
# 581 2020-08-02 14:05:45.856            Kalyani        Pune
# 582 2020-08-02 20:13:55.905        Prathyusha   Kondapalli
# 583 2020-08-04 01:22:17.969          Munnawar         Pune
# 584 2020-08-04 08:51:10.272             Souvik    Guwahati
# 585 2020-09-11 19:01:30.905              Manan        Pune
#
#          MasterClass Name
# 0    Basic Video Editting
# 1    Basic Video Editting
# 2    Basic Video Editting
# 3    Basic Video Editting
# 4    Basic Video Editting
# ..                    ...
# 581  Basic Video Editting
# 582  Basic Video Editting
# ...

# %%
mc_ve_df.to_excel(r'C:\Users\Alina Sahoo\Documents\MKR\Task2\MC7.xlsx', index = False)
